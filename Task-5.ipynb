# %% [markdown]
# 1. Import the required modules

# %%
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %% [markdown]
# 2. Import the required dataset

# %%
df = pd.read_csv("cleaned_sales_data.csv")

# %% [markdown]
# 3. Data Cleaning

# %%
df.dropna(how="any")
df.drop_duplicates()
# Out:
#       row_id        order_id  order_date   ship_date       ship_mode  \
# 0          0  CA-2017-152156  2017-11-08  2017-11-11    second class
# 1          1  CA-2017-152156  2017-11-08  2017-11-11    second class
# 2          2  CA-2017-138688  2017-06-12  2017-06-16    second class
# 3          3  US-2016-108966  2016-10-11  2016-10-18  standard class
# 4          4  US-2016-108966  2016-10-11  2016-10-18  standard class
# ...      ...             ...         ...         ...             ...
# 9784    9784  CA-2017-125920  2017-05-21  2017-05-28  standard class
# 9785    9785  CA-2016-128608  2016-01-12  2016-01-17  standard class
# 9786    9786  CA-2016-128608  2016-01-12  2016-01-17  standard class
# 9787    9787  CA-2016-128608  2016-01-12  2016-01-17  standard class
# 9788    9788  CA-2016-128608  2016-01-12  2016-01-17  standard class
#
#      customer_id     customer_name    segment        country             city  \
# 0       CG-12520       Claire Gute   consumer  United States        Henderson
# 1       CG-12520       Claire Gute   consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9784    SH-19975     Sally Hughsby  corporate  United States          Chicago
# 9785    CS-12490  Cindy Schnelling  corporate  United States           Toledo
# 9786    CS-12490  Cindy Schnelling  corporate  United States           Toledo
# 9787    CS-12490  Cindy Schnelling  corporate  United States           Toledo
# 9788    CS-12490  Cindy Schnelling  corporate  United States           Toledo
#
#       ...   region       product_id         category sub_category  \
# 0     ...    South  FUR-BO-10001798        furniture    bookcases
# 1     ...    South  FUR-CH-10000454        furniture       chairs
# 2     ...     West  OFF-LA-10000240  office supplies       labels
# 3     ...    South  FUR-TA-10000577        furniture       tables
# 4     ...    South  OFF-ST-10000760  office supplies      storage
# ...   ...      ...              ...              ...          ...
# 9784  ...  Central  OFF-BI-10003429  office supplies      binders
# 9785  ...     East  OFF-AR-10001374  office supplies          art
# 9786  ...     East  TEC-PH-10004977       technology       phones
# 9787  ...     East  TEC-PH-10000912       technology       phones
# 9788  ...     East  TEC-AC-10000487       technology  accessories
#
#                                            product_name    cost   price  \
# 0                     Bush Somerset Collection Bookcase  464.48  901.06
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  756.10  138.70
# 2     Self-Adhesive Address Labels For Typewriters B...  537.68  159.28
# 3         Bretford Cr4500 Series Slim Rectangular Table  875.91  445.88
# 4                        Eldon Fold 'N Roll Cart System  187.17  137.59
# ...                                                 ...     ...     ...
# 9784  Cardinal Holdit! Binder Insert Strips,Extra St...  390.95  716.41
# 9785           Bic Brite Liner Highlighters, Chisel Tip  377.87  671.92
# 9786                                        Ge 30524Ee4  296.25  419.67
# 9787           Anker 24W Portable Micro Usb Car Charger   60.04   95.60
# 9788                Sandisk Cruzer 4 Gb Usb Flash Drive  173.11  122.00
#
#       profit  quantity        sales
# 0     436.58         4  3604.243977
# 1    -617.40        12  1664.369269
# 2    -378.40        12  1911.397750
# 3    -430.03        13  5796.463018
# 4     -49.58        19  2614.284944
# ...      ...       ...          ...
# 9784  325.46         6  4298.456294
# 9785  294.05         3  2015.759993
# 9786  123.42        23  9652.397717
# 9787   35.56         4   382.392219
# 9788  -51.11         6   731.976324
#
# [9789 rows x 22 columns]

# %% [markdown]
# 4. Dataset Overview

# %%
print(df.describe(include="all"))
df.info()
print(df['segment'].value_counts())
# Out:
#              row_id        order_id  order_date   ship_date       ship_mode  \
# count   9789.000000            9789        9789        9789            9789
# unique          NaN            4916        1229        1326               4
# top             NaN  CA-2018-100111  2017-09-05  2018-09-26  standard class
# freq            NaN              14          38          34            5849
# mean    4894.000000             NaN         NaN         NaN             NaN
# std     2825.985226             NaN         NaN         NaN             NaN
# min        0.000000             NaN         NaN         NaN             NaN
# 25%     2447.000000             NaN         NaN         NaN             NaN
# 50%     4894.000000             NaN         NaN         NaN             NaN
# 75%     7341.000000             NaN         NaN         NaN             NaN
# max     9788.000000             NaN         NaN         NaN             NaN
#
#        customer_id  customer_name   segment        country           city  \
# count         9789           9789      9789           9789           9789
# unique         793            793         3              1            529
# top       WB-21850  William Brown  consumer  United States  New York City
# freq            35             35      5096           9789            891
# mean           NaN            NaN       NaN            NaN            NaN
# std            NaN            NaN       NaN            NaN            NaN
# min            NaN            NaN       NaN            NaN            NaN
# 25%            NaN            NaN       NaN            NaN            NaN
# 50%            NaN            NaN       NaN            NaN            NaN
# 75%            NaN            NaN       NaN            NaN            NaN
# max            NaN            NaN       NaN            NaN            NaN
#
#         ... region       product_id         category sub_category  \
# count   ...   9789             9789             9789         9789
# unique  ...      4             1860                3           17
# top     ...   West  OFF-PA-10001970  office supplies      binders
# freq    ...   3140               18             5903         1492
# mean    ...    NaN              NaN              NaN          NaN
# std     ...    NaN              NaN              NaN          NaN
# min     ...    NaN              NaN              NaN          NaN
# 25%     ...    NaN              NaN              NaN          NaN
# 50%     ...    NaN              NaN              NaN          NaN
# 75%     ...    NaN              NaN              NaN          NaN
# max     ...    NaN              NaN              NaN          NaN
#
#            product_name         cost        price       profit     quantity  \
# count              9789  9789.000000  9789.000000  9789.000000  9789.000000
# unique             1848          NaN          NaN          NaN          NaN
# top     Staple Envelope          NaN          NaN          NaN          NaN
# freq                 47          NaN          NaN          NaN          NaN
# mean                NaN   501.568658   501.607251     0.038523    12.968638
# std                 NaN   288.090708   287.178132   407.271712     7.241735
# min                 NaN     1.320000     1.060000  -978.860000     1.000000
# 25%                 NaN   251.600000   252.970000  -290.520000     7.000000
# 50%                 NaN   502.790000   503.960000    -2.550000    13.000000
# 75%                 NaN   750.440000   744.540000   284.210000    19.000000
# max                 NaN   999.880000   999.920000   994.500000    25.000000
#
#                sales
# count    9789.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean     6505.827106
# std      5616.279172
# min         3.401739
# 25%      1879.245447
# 50%      4894.443913
# 75%      9879.910496
# max     24973.493980
#
# [11 rows x 22 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9789 entries, 0 to 9788
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row_id         9789 non-null   int64
#  1   order_id       9789 non-null   object
#  2   order_date     9789 non-null   object
#  3   ship_date      9789 non-null   object
#  4   ship_mode      9789 non-null   object
#  5   customer_id    9789 non-null   object
#  6   customer_name  9789 non-null   object
#  7   segment        9789 non-null   object
#  8   country        9789 non-null   object
#  9   city           9789 non-null   object
#  10  state          9789 non-null   object
#  11  postal_code    9789 non-null   int64
#  12  region         9789 non-null   object
#  13  product_id     9789 non-null   object
#  14  category       9789 non-null   object
#  15  sub_category   9789 non-null   object
#  16  product_name   9789 non-null   object
#  17  cost           9789 non-null   float64
#  18  price          9789 non-null   float64
#  19  profit         9789 non-null   float64
#  20  quantity       9789 non-null   int64
#  21  sales          9789 non-null   float64
# dtypes: float64(4), int64(3), object(15)
# memory usage: 1.6+ MB
# segment
# consumer       5096
# corporate      2948
# home office    1745
# Name: count, dtype: int64

# %% [markdown]
# 5. Visual Analysis

# %% [markdown]
# 5.1. PairPlot

# %%
sns.pairplot(df.sample(1000), hue="segment", diag_kind="kde")
mpl.pyplot.savefig("pairplot.png")
mpl.pyplot.clf()

# %% [markdown]
# 5.2. Heatmap

# %%
tempdf = df.copy()
tempdf.drop(columns=["row_id", "order_id", "order_date", "ship_date", "ship_mode", "customer_name", "customer_id", "segment", "country", "city", "state", "postal_code", "region", "product_id", "category", "sub_category", "product_name"], inplace=True)
sns.heatmap(tempdf.corr(), annot=True, cmap="coolwarm")
mpl.pyplot.title("Correlation Heatmap")
mpl.pyplot.savefig("heatmap.png")
mpl.pyplot.clf()

# %% [markdown]
# 5.3. Histogram

# %%
sns.histplot(data=df, x="sales", bins=30, kde=True)
mpl.pyplot.title("Sales Distribution")
mpl.pyplot.xlabel("Sales Amount")
mpl.pyplot.ylabel("Frequency")
mpl.pyplot.savefig("sales_histogram.png")
mpl.pyplot.clf()

# %% [markdown]
# 5.4. BoxPlot

# %%
sns.boxplot(data=df, x="region", y="sales", hue="segment")
mpl.pyplot.xlabel("Region")
mpl.pyplot.ylabel("Sales")
mpl.pyplot.title("Sales by Region and Segment")
mpl.pyplot.legend(title="Segment")
mpl.pyplot.savefig("sales_region_boxplot.png")
mpl.pyplot.clf()

# %% [markdown]
# 5.5. ScatterPlot

# %%
sns.scatterplot(data=df, x="profit", y="cost", hue="region", size="sales")
mpl.pyplot.title("Cost vs Profit by Region")
mpl.pyplot.savefig("profit_cost_scatterplot.png")
mpl.pyplot.clf()
